# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import numpy as np
import scipy
from scipy import ndimage

# %%
img = scipy.misc.imread("./data/image.png")
plt.figure()
plt.imshow(img)

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
plt.imshow(img)

plt.subplot(2,2,2)
plt.imshow(ndimage.rotate(img, 90))

plt.subplot(2,2,3)
nored = img.copy()
nored[:,:,0] = np.zeros(nored[:,:,0].shape)
plt.imshow(nored)

plt.subplot(2,2,4)
onlyred = img.copy()
onlyred[:,:,1] = np.zeros(onlyred[:,:,1].shape)
onlyred[:,:,2] = np.zeros(onlyred[:,:,2].shape)
plt.imshow(onlyred)
